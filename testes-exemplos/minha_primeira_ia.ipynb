# %% [markdown]
# https://www.tensorflow.org/tutorials/keras/classification

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_labels[0]
# Out:
# 9

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.6412 - accuracy: 0.7741
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3822 - accuracy: 0.8638
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3362 - accuracy: 0.8775
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3128 - accuracy: 0.8859
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2994 - accuracy: 0.8895
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2879 - accuracy: 0.8935
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2659 - accuracy: 0.9014
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2630 - accuracy: 0.9009
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2497 - accuracy: 0.9068
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2389 - accuracy: 0.9088

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3399 - accuracy: 0.8828
#
# Test accuracy: 0.8827999830245972

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([2.5644069e-06, 3.7546524e-08, 2.5681979e-08, 7.7649914e-11,
#        1.2283238e-07, 1.1490629e-03, 1.2804189e-06, 5.3906902e-03,
#        6.4859534e-10, 9.9345618e-01], dtype=float32)

# %% [markdown]
# Relu:
# ![](https://machinelearningmastery.com/wp-content/uploads/2018/10/Line-Plot-of-Rectified-Linear-Activation-for-Negative-and-Positive-Inputs.png)
